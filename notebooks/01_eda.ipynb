# %% [markdown]
# Before building any model, we must clearly understand:
#
# 1. What are the input features (X)?
#
# 2. What are the target variables (y)?
#
# 3. How are they aligned?
#
# 4. What is the prediction task type (regression or classification)?
#
# This dataset is separated into two files:
#
# smartphone_battery_features.csv → engineered input features
#
# smartphone_battery_targets.csv → ground truth battery health and replacement recommendation
#
# Since features and targets are stored separately, the first engineering task is data alignment.

# %% [markdown]
# We need to:
#
# - Inspect shapes of both datasets
#
# - Check whether there is a common identifier column
#
# - Verify if row ordering matches
#
# - Identify the target column(s)
#
# - Determine the prediction problem type

# %%
import pandas as pd

# load feature
X = pd.read_csv("../data/raw/smartphone_battery_features.csv")
y = pd.read_csv("../data/raw/smartphone_battery_targets.csv")

print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nX columns:")
print(list(X.columns))

print("\ny columns:")
print(list(y.columns))
# Out:
# X shape: (5000, 15)
# y shape: (5000, 3)
#
# X columns:
# ['Device_ID', 'device_age_months', 'battery_capacity_mah', 'avg_screen_on_hours_per_day', 'avg_charging_cycles_per_week', 'avg_battery_temp_celsius', 'fast_charging_usage_percent', 'overnight_charging_freq_per_week', 'gaming_hours_per_week', 'video_streaming_hours_per_week', 'background_app_usage_level', 'signal_strength_avg', 'charging_habit_score', 'usage_intensity_score', 'thermal_stress_index']
#
# y columns:
# ['Device_ID', 'current_battery_health_percent', 'recommended_action']

# %%
print("\nX head:")
print(X.head())
# Out:
# X head:
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95

# %%
print("\ny head:")
print(y.head())
# Out:
# y head:
#                               Device_ID  current_battery_health_percent  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                            32.8
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                            50.3
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                            66.1
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                            46.8
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                            67.2
#
#   recommended_action
# 0       Change Phone
# 1    Replace Battery
# 2    Replace Battery
# 3       Change Phone
# 4    Replace Battery

# %%
print("\nX info:")
X.info()
# Out:
# X info:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Device_ID                         5000 non-null   str
#  1   device_age_months                 5000 non-null   int64
#  2   battery_capacity_mah              5000 non-null   int64
#  3   avg_screen_on_hours_per_day       5000 non-null   float64
#  4   avg_charging_cycles_per_week      5000 non-null   float64
#  5   avg_battery_temp_celsius          5000 non-null   float64
#  6   fast_charging_usage_percent       5000 non-null   float64
#  7   overnight_charging_freq_per_week  5000 non-null   int64
#  8   gaming_hours_per_week             5000 non-null   float64
#  9   video_streaming_hours_per_week    5000 non-null   float64
#  10  background_app_usage_level        5000 non-null   str
#  11  signal_strength_avg               5000 non-null   str
#  12  charging_habit_score              5000 non-null   int64
#  13  usage_intensity_score             5000 non-null   float64
#  14  thermal_stress_index              5000 non-null   float64
# dtypes: float64(8), int64(4), str(3)
# memory usage: 586.1 KB

# %%
print("\ny info:")
y.info()
# Out:
# y info:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Device_ID                       5000 non-null   str
#  1   current_battery_health_percent  5000 non-null   float64
#  2   recommended_action              5000 non-null   str
# dtypes: float64(1), str(2)
# memory usage: 117.3 KB

# %% [markdown]
# Dataset Overview
#
# We are given two separate files:
#
# smartphone_battery_features.csv (X)
#
# smartphone_battery_targets.csv (y)
#
# Shape Check
#
# X shape: (5000, 15)
#
# y shape: (5000, 3)
#
# Both datasets contain 5000 rows, indicating potential row-level alignment.
#
# Key Observations
# 1. Identifier Column
#
# Both X and y contain a common column:
#
# Device_ID
#
# This suggests we should merge using Device_ID instead of assuming row ordering alignment.
#
# 2. Feature Types (X)
#
# Numerical features:
#
# int64: 4
#
# float64: 8
#
# Categorical features:
#
# 3 string columns:
#
# Device_ID
#
# background_app_usage_level
#
# signal_strength_avg
#
# No missing values detected.
#
# 3. Target Variables (y)
#
# Columns:
#
# current_battery_health_percent → Continuous variable (float64)
#
# recommended_action → Categorical variable (string)
#
# This indicates a multi-task prediction setup:
#
# Regression task → battery health %
#
# Classification task → recommended action
#
# Initial Conclusion
#
# We are dealing with a supervised multi-task learning problem.
#
# Next step:
# Merge X and y using Device_ID and construct a unified dataset.

# %%
df = pd.merge(X, y,  on = 'Device_ID', how = 'inner')

print(df.shape)
df.head()
# Out:
# (5000, 17)
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index  \
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95
#
#    current_battery_health_percent recommended_action
# 0                            32.8       Change Phone
# 1                            50.3    Replace Battery
# 2                            66.1    Replace Battery
# 3                            46.8       Change Phone
# 4                            67.2    Replace Battery

# %%
target_reg = 'current_battery_health_percent'
X_full = df.drop(columns = ['Device_ID', 'current_battery_health_percent', 'recommended_action'])
y_reg = df[target_reg]

# %%
#split train/test set 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_full, y_reg, test_size=0.2, random_state=42
)

# %% [markdown]
# Objective
#
# Build a reproducible baseline regression pipeline to predict:
#
# - current_battery_health_percent (battery health %)
#
# This phase focuses on establishing an end-to-end workflow that is:
#
# - Repeatable (same result every run given a fixed random seed)
#
# - Leakage-safe (no training information leaking into test preprocessing)
#
# - Modular (easy to swap models later)

# %%
cat_cols = X_train.select_dtypes(include="object").columns.tolist()
num_cols = X_train.select_dtypes(exclude="object").columns.tolist()

print("cat_cols:", cat_cols)
print("num_cols:", num_cols)
# Out:
# cat_cols: ['background_app_usage_level', 'signal_strength_avg']
# num_cols: ['device_age_months', 'battery_capacity_mah', 'avg_screen_on_hours_per_day', 'avg_charging_cycles_per_week', 'avg_battery_temp_celsius', 'fast_charging_usage_percent', 'overnight_charging_freq_per_week', 'gaming_hours_per_week', 'video_streaming_hours_per_week', 'charging_habit_score', 'usage_intensity_score', 'thermal_stress_index']
# /var/folders/fp/y0r76_rn5hq4p7ndc5tmspjm0000gn/T/ipykernel_49129/4292107656.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = X_train.select_dtypes(include="object").columns.tolist()

# %%
#Numerical features → StandardScaler
#Categorical features → OneHotEncoder

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocess = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

preprocess
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['device_age_months', 'battery_capacity_mah',
#                                   'avg_screen_on_hours_per_day',
#                                   'avg_charging_cycles_per_week',
#                                   'avg_battery_temp_celsius',
#                                   'fast_charging_usage_percent',
#                                   'overnight_charging_freq_per_week',
#                                   'gaming_hours_per_week',
#                                   'video_streaming_hours_per_week',
#                                   'charging_habit_score',
#                                   'usage_intensity_score',
#                                   'thermal_stress_index']),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['background_app_usage_level',
#                                   'signal_strength_avg'])])

# %% [markdown]
# We now combine:
#
# - Preprocessing (ColumnTransformer)
#
# - Model (Ridge Regression)
#
# into a single Pipeline object.

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score

#step 1 : Define model
model = Ridge()

#step 2 : Build pipeline
pipe = Pipeline(
    steps=[
        ('preprocess', preprocess),
        ('model', model)
    ]
)

pipe

# %% [markdown]
# We now train the complete pipeline on the training set and evaluate it on the test set.
#
# - fit() learns preprocessing parameters (scaling, encoding) only from training data, preventing data leakage.
#
# - predict() applies the same transformations to the test set before generating predictions.
#
# Evaluation Metrics
#
# - MAE → Average prediction error (battery health percentage points).
#
# - R² → Proportion of variance explained by the model.
#
# This baseline establishes a reference point for future model improvements.

# %%
pipe.fit(X_train, y_train)

pred = pipe.predict(X_test)

mae = mean_absolute_error(y_test, pred)
r2 = r2_score(y_test, pred)

print("MAE:", mae)
print("R2:", r2)
# Out:
# MAE: 3.681842866502536
# R2: 0.9298347173896626

# %% [markdown]
# To understand which features influence battery health,
# we examine the learned coefficients from the Ridge regression model.
#
# Because preprocessing (scaling + one-hot encoding) was applied,
# we must extract feature names after transformation before interpreting coefficients.

# %%
import numpy as np
import pandas as pd

# 取得轉換後的 feature 名稱
feature_names = pipe.named_steps["preprocess"].get_feature_names_out()

# 取得 Ridge 係數
coefficients = pipe.named_steps["model"].coef_

# 建立 DataFrame
coef_df = pd.DataFrame({
    "feature": feature_names,
    "coefficient": coefficients
})

# 依絕對值排序
coef_df["abs_coef"] = np.abs(coef_df["coefficient"])
coef_df = coef_df.sort_values("abs_coef", ascending=False)

coef_df.head(10)
# Out:
#                                  feature  coefficient   abs_coef
# 0                 num__device_age_months   -15.103489  15.103489
# 3      num__avg_charging_cycles_per_week    -5.945355   5.945355
# 11             num__thermal_stress_index    -3.099095   3.099095
# 9              num__charging_habit_score     1.750317   1.750317
# 7             num__gaming_hours_per_week     0.976977   0.976977
# 4          num__avg_battery_temp_celsius    -0.371010   0.371010
# 10            num__usage_intensity_score    -0.138713   0.138713
# 5       num__fast_charging_usage_percent     0.128729   0.128729
# 12  cat__background_app_usage_level_High     0.106973   0.106973
# 1              num__battery_capacity_mah    -0.099444   0.099444
